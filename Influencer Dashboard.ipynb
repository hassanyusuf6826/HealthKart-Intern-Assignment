# %% [markdown]
# # Steamlit Dashboard Development

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# ---------------------------
# Load data with caching
# ---------------------------
@st.cache_data
def load_data():
    influencers = pd.read_csv("influencers.csv")
    posts = pd.read_csv("posts.csv")
    tracking = pd.read_csv("tracking_data.csv")
    payouts = pd.read_csv("payouts.csv")
    metrics = pd.read_csv("influencer_metrics.csv")
    return influencers, posts, tracking, payouts, metrics

influencers, posts, tracking, payouts, metrics = load_data()

# ---------------------------
# Title
# ---------------------------
st.title("📊 HealthKart Influencer Campaign Dashboard")

# ---------------------------
# Sidebar Filters
# ---------------------------
st.sidebar.header("🔍 Filter Influencers")

platforms = st.sidebar.multiselect(
    "Select Platform", options=metrics["platform"].unique(), default=metrics["platform"].unique()
)
categories = st.sidebar.multiselect(
    "Select Category", options=metrics["category"].unique(), default=metrics["category"].unique()
)
genders = st.sidebar.multiselect(
    "Select Gender", options=metrics["gender"].unique(), default=metrics["gender"].unique()
)
tiers = st.sidebar.multiselect(
    "Select Influencer Tier", options=metrics["tier"].unique(), default=metrics["tier"].unique()
)

# Apply filters
filtered = metrics[
    (metrics["platform"].isin(platforms)) &
    (metrics["category"].isin(categories)) &
    (metrics["gender"].isin(genders)) &
    (metrics["tier"].isin(tiers))
]

# ---------------------------
# KPIs
# ---------------------------
st.subheader("📈 Key Metrics")
col1, col2, col3 = st.columns(3)
col1.metric("Total Revenue", f"${filtered['total_revenue'].sum():,.2f}")
col2.metric("Total Payout", f"${filtered['total_payout'].sum():,.2f}")
col3.metric("Average ROAS", f"{filtered['ROAS'].mean():.2f}")

# ---------------------------
# Influencer Table
# ---------------------------
st.markdown("### 📋 Influencer Performance")
st.dataframe(
    filtered.sort_values(by="ROAS", ascending=False),
    use_container_width=True
)

# ---------------------------
# Visual 1: ROAS Distribution
# ---------------------------
st.markdown("### 📊 ROAS Distribution")
fig1 = px.histogram(filtered, x="ROAS", nbins=25, title="Distribution of ROAS")
st.plotly_chart(fig1, use_container_width=True)

# ---------------------------
# Visual 2: Engagement Rate vs ROAS
# ---------------------------
st.markdown("### 💬 Engagement Rate vs ROAS")
fig2 = px.scatter(
    filtered,
    x="engagement_rate",
    y="ROAS",
    size="follower_count",
    color="platform",
    hover_name="name",
    title="Engagement vs ROAS by Platform"
)
st.plotly_chart(fig2, use_container_width=True)

# ---------------------------
# Visual 3: Top Payout Efficiency
# ---------------------------
st.markdown("### 💵 Top 10 Payout-Efficient Influencers")
top_eff = filtered.sort_values(by="payout_efficiency", ascending=False).head(10)
fig3 = px.bar(
    top_eff,
    x="name",
    y="payout_efficiency",
    color="platform",
    title="Top 10 Influencers by Payout Efficiency"
)
st.plotly_chart(fig3, use_container_width=True)

# ---------------------------
# Download CSV
# ---------------------------
st.download_button(
    label="📥 Download Filtered Data as CSV",
    data=filtered.to_csv(index=False),
    file_name="filtered_influencer_metrics.csv",
    mime="text/csv"
)

st.caption("Built for the HealthKart Intern Assignment · Data simulated for demo purposes.")
# Out:
# 2025-07-24 07:00:46.794 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-07-24 07:00:46.800 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-07-24 07:00:46.800 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.781
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\USER\anaconda3\envs\tf_env\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-07-24 07:00:48.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:48.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:49.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 07:00:50.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
